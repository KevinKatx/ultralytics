# %%
import sys
sys.path.append("path/to/your/modified/ultralytics")

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Clear Turbidity

# %%
from ultralytics import YOLO

###No CBAM

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Clear).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Early And Late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-early&lateBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Clear).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-lateBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Clear).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###early Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-earlyBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Clear).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck Only

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neckOnly.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Clear).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###preDetect

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-preDetect.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Clear).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck and Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neck&BBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Clear).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###YOLO11

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\11\yolo11.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Clear).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %% [markdown]
# # Low Turbidity

# %%
from ultralytics import YOLO

###No CBAM

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Low)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.58 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Early And Late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-early&lateBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Low)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.58 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-lateBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Low)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.58 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###early Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-earlyBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Low)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.59 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck Only

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neckOnly.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Low)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.59 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###preDetect

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-preDetect.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Low)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.59 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck and Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neck&BBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Low)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.59 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###YOLO11

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\11\yolo11.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Low)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.59 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %% [markdown]
# # Medium Turbidity

# %%
from ultralytics import YOLO

###No CBAM

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Medium)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Early And Late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-early&lateBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Medium)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
#       2/100      2.32G     0.4058      6.636      3.411         11        640: 100% ━━━━━━━━━━━━ 93/93 5.5it/s 16.8s0.1s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.32G     0.3859       6.28       3.27          9        640: 100% ━━━━━━━━━━━━ 93/93 5.9it/s 15.6s0.1s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.32G      0.345      5.948      3.006         14        640: 100% ━━━━━━━━━━━━ 93/93 5.9it/s 15.8s0.2s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.32G     0.3091      5.719      2.819         15        640: 100% ━━━━━━━━━━━━ 93/93 6.0it/s 15.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.9it/s 1.8s0.3s
#                    all        221        377      0.456      0.326      0.253       0.09
#
# ...

# %%
from ultralytics import YOLO

###late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-lateBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Medium)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.59 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###early Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-earlyBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Medium)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.59 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck Only

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neckOnly.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Medium)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###preDetect

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-preDetect.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Medium)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck and Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neck&BBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Medium)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###YOLO11

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\11\yolo11.yaml')  # build a new model from YAML
results = model.train(data='Underwater(Medium)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %% [markdown]
# # High Turbidity

# %%
from ultralytics import YOLO

###No CBAM

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8.yaml')  # build a new model from YAML
results = model.train(data='Underwater(High)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Early And Late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-early&lateBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(High)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-lateBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(High)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###early Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-earlyBBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(High)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck Only

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neckOnly.yaml')  # build a new model from YAML
results = model.train(data='Underwater(High)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###preDetect

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-preDetect.yaml')  # build a new model from YAML
results = model.train(data='Underwater(High)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck and Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neck&BBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater(High)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###YOLO11

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\11\yolo11.yaml')  # build a new model from YAML
results = model.train(data='Underwater(High)(CLAHE).yaml', # Epoch settings
    epochs=100,              # you would stop early if needed
    patience=30,            # early stopping enabled

    # Batch & optimizer
    batch=16,
    optimizer="Adam",       # or "SGD"

    # Learning rate + scheduler
    lr0=0.001,
    warmup_epochs=3,
    cos_lr=True,            # cosine decay with warm-up

    # Loss components
    box=1.0,                # IoU-based box loss
    cls=1.0,                # classification loss (BCE internally)
    dfl=1.5,                # optional depending on model

    # Validation
    val=True,
    imgsz=640)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...
