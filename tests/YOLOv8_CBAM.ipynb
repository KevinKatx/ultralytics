# %%
import sys
sys.path.append("path/to/your/modified/ultralytics")

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO

###No CBAM

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8.yaml')  # build a new model from YAML
results = model.train(data='Underwater.yaml', epochs=100, imgsz=320)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.10 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###With CBAM on every neck feature

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM.yaml')  # build a new model from YAML
results = model.train(data='Underwater.yaml', epochs=100, imgsz=320)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.10 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###late Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM.yaml')  # build a new model from YAML
results = model.train(data='Underwater.yaml', epochs=100, imgsz=320)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.12 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck Only

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neckOnly.yaml')  # build a new model from YAML
results = model.train(data='Underwater.yaml', epochs=100, imgsz=320)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.12 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###preDetect

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-preDetect.yaml')  # build a new model from YAML
results = model.train(data='Underwater.yaml', epochs=100, imgsz=320)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.12 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...

# %%
from ultralytics import YOLO

###Neck and Backbone

model = YOLO(r'C:\Clone Repos\Modified-Ultralytics-for-CBAM-Implementation-of-YOLOv8\ultralytics\cfg\models\v8\yolov8-CBAM-neck&BBone.yaml')  # build a new model from YAML
results = model.train(data='Underwater.yaml', epochs=100, imgsz=320)  # train the model
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.13 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.11.9 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# ...
